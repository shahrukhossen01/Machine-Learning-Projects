# %%
import pandas as pd

# %%
pwd()
# Out:
# 'E:\\Different batch\\Weekened\\PMAS-DS, Fall-2021\\Data'

# %%
import os

# %%
os.chdir("E:\\Different batch\\Weekened\\PMAS-DS, Fall-2021\\Data")

# %%
df=pd.read_csv("mall customers.csv")

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.rename(columns={'Annual Income (k$)':'income','Spending Score (1-100)':'score'},inplace='True')

# %%
df
# Out:
#      CustomerID  Gender  Age  income  score
# 0             1    Male   19      15     39
# 1             2    Male   21      15     81
# 2             3  Female   20      16      6
# 3             4  Female   23      16     77
# 4             5  Female   31      17     40
# ..          ...     ...  ...     ...    ...
# 195         196  Female   35     120     79
# 196         197  Female   45     126     28
# 197         198    Male   32     126     74
# 198         199    Male   32     137     18
# 199         200    Male   30     137     83
#
# [200 rows x 5 columns]

# %%
df=df.drop(['CustomerID','Gender','Age'],axis=1)

# %%
df
# Out:
#      income  score
# 0        15     39
# 1        15     81
# 2        16      6
# 3        16     77
# 4        17     40
# ..      ...    ...
# 195     120     79
# 196     126     28
# 197     126     74
# 198     137     18
# 199     137     83
#
# [200 rows x 2 columns]

# %%
from sklearn import cluster

# %%
from sklearn.cluster import KMeans

# %%
import numpy as np

# %%
kmeans=cluster.KMeans()

# %%
kmeans
# Out:
# KMeans()

# %%
fit=kmeans.fit(df[['income','score']])

# %%
fit
# Out:
# KMeans()

# %%
clusters=kmeans.labels_

# %%
clusters
# Out:
# array([1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4,
#        1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 1, 4, 3, 4, 3, 3,
#        1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 7, 3, 3, 7, 3, 3, 3, 3, 3,
#        3, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 0, 5, 0, 7, 0, 5, 0, 5, 0,
#        7, 0, 5, 0, 5, 0, 5, 0, 5, 0, 7, 0, 5, 0, 7, 0, 5, 0, 5, 0, 5, 0,
#        5, 0, 5, 0, 5, 0, 7, 0, 5, 0, 5, 0, 5, 0, 5, 0, 5, 0, 5, 0, 5, 0,
#        5, 0, 5, 0, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6,
#        2, 6])

# %%
centers=kmeans.cluster_centers_

# %%
centers
# Out:
# array([[ 78.55172414,  82.17241379],
#        [ 25.14285714,  19.52380952],
#        [109.7       ,  22.        ],
#        [ 47.44444444,  51.24444444],
#        [ 25.0952381 ,  80.04761905],
#        [ 79.73913043,  13.39130435],
#        [109.7       ,  82.        ],
#        [ 63.80487805,  46.63414634]])

# %%
df['clusters']=clusters

# %%
df
# Out:
#      income  score  clusters
# 0        15     39         1
# 1        15     81         4
# 2        16      6         1
# 3        16     77         4
# 4        17     40         1
# ..      ...    ...       ...
# 195     120     79         6
# 196     126     28         2
# 197     126     74         6
# 198     137     18         2
# 199     137     83         6
#
# [200 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['income'],df['score'])
plt.title('scatter plot')
plt.xlabel('income')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
df0=df[df.clusters==0]
df1=df[df.clusters==1]
df2=df[df.clusters==2]
df3=df[df.clusters==3]
df4=df[df.clusters==4]
df5=df[df.clusters==5]
df6=df[df.clusters==6]
df7=df[df.clusters==7]

# %%
df0
# Out:
#      income  score  clusters
# 123      69     91         0
# 125      70     77         0
# 127      71     95         0
# 129      71     75         0
# 131      71     75         0
# 133      72     71         0
# 135      73     88         0
# 137      73     73         0
# 139      74     72         0
# 141      75     93         0
# 143      76     87         0
# 145      77     97         0
# 147      77     74         0
# 149      78     90         0
# 151      78     88         0
# 153      78     76         0
# 155      78     89         0
# 157      78     78         0
# 159      78     73         0
# 161      79     83         0
# 163      81     93         0
# 165      85     75         0
# 167      86     95         0
# 169      87     63         0
# 171      87     75         0
# 173      87     92         0
# 175      88     86         0
# 177      88     69         0
# 179      93     90         0

# %%
df1
# Out:
#     income  score  clusters
# 0       15     39         1
# 2       16      6         1
# 4       17     40         1
# 6       18      6         1
# 8       19      3         1
# 10      19     14         1
# 12      20     15         1
# 14      20     13         1
# 16      21     35         1
# 18      23     29         1
# 20      24     35         1
# 22      25      5         1
# 24      28     14         1
# 26      28     32         1
# 28      29     31         1
# 30      30      4         1
# 32      33      4         1
# 34      33     14         1
# 36      34     17         1
# 38      37     26         1
# 44      39     28         1

# %%
df2
# Out:
#      income  score  clusters
# 180      97     32         2
# 182      98     15         2
# 184      99     39         2
# 186     101     24         2
# 188     103     17         2
# 190     103     23         2
# 192     113      8         2
# 194     120     16         2
# 196     126     28         2
# 198     137     18         2

# %%
df3
# Out:
#     income  score  clusters
# 40      38     35         3
# 42      39     36         3
# 43      39     61         3
# 45      39     65         3
# 46      40     55         3
# 47      40     47         3
# 48      40     42         3
# 49      40     42         3
# 50      42     52         3
# 51      42     60         3
# 52      43     54         3
# 53      43     60         3
# 54      43     45         3
# 55      43     41         3
# 56      44     50         3
# 57      44     46         3
# 58      46     51         3
# 59      46     46         3
# 60      46     56         3
# 61      46     55         3
# 62      47     52         3
# 63      47     59         3
# 64      48     51         3
# 65      48     59         3
# 66      48     50         3
# 67      48     48         3
# 68      48     59         3
# 69      48     47         3
# 70      49     55         3
# 71      49     42         3
# 72      50     49         3
# 73      50     56         3
# ...

# %%
df4
# Out:
#     income  score  clusters
# 1       15     81         4
# 3       16     77         4
# 5       17     76         4
# 7       18     94         4
# 9       19     72         4
# 11      19     99         4
# 13      20     77         4
# 15      20     79         4
# 17      21     66         4
# 19      23     98         4
# 21      24     73         4
# 23      25     73         4
# 25      28     82         4
# 27      28     61         4
# 29      29     87         4
# 31      30     73         4
# 33      33     92         4
# 35      33     81         4
# 37      34     73         4
# 39      37     75         4
# 41      38     92         4

# %%
df5
# Out:
#      income  score  clusters
# 124      70     29         5
# 128      71     11         5
# 130      71      9         5
# 134      73      5         5
# 136      73      7         5
# 138      74     10         5
# 140      75      5         5
# 144      77     12         5
# 148      78     22         5
# 150      78     17         5
# 152      78     20         5
# 154      78     16         5
# 156      78      1         5
# 158      78      1         5
# 162      81      5         5
# 164      85     26         5
# 166      86     20         5
# 168      87     27         5
# 170      87     13         5
# 172      87     10         5
# 174      88     13         5
# 176      88     15         5
# 178      93     14         5

# %%
df6
# Out:
#      income  score  clusters
# 181      97     86         6
# 183      98     88         6
# 185      99     97         6
# 187     101     68         6
# 189     103     85         6
# 191     103     69         6
# 193     113     91         6
# 195     120     79         6
# 197     126     74         6
# 199     137     83         6

# %%
df7
# Out:
#      income  score  clusters
# 79       54     42         7
# 82       54     41         7
# 89       58     46         7
# 90       59     55         7
# 91       59     41         7
# 92       60     49         7
# 93       60     40         7
# 94       60     42         7
# 95       60     52         7
# 96       60     47         7
# 97       60     50         7
# 98       61     42         7
# 99       61     49         7
# 100      62     41         7
# 101      62     48         7
# 102      62     59         7
# 103      62     55         7
# 104      62     56         7
# 105      62     42         7
# 106      63     50         7
# 107      63     46         7
# 108      63     43         7
# 109      63     48         7
# 110      63     52         7
# 111      63     54         7
# 112      64     42         7
# 113      64     46         7
# 114      65     48         7
# 115      65     50         7
# 116      65     43         7
# 117      65     59         7
# ...

# %%
plt.scatter(df0['income'],df0['score'],color='black')
plt.scatter(df1['income'],df1['score'],color='yellow')
plt.scatter(df2['income'],df2['score'],color='blue')
plt.scatter(df3['income'],df3['score'],color='pink')
plt.scatter(df4['income'],df4['score'],color='purple')
plt.scatter(df5['income'],df5['score'],color='green')
plt.scatter(df6['income'],df6['score'],color='violet')
plt.scatter(df7['income'],df7['score'],color='orange')

# %%
plt.scatter(df0['income'],df0['score'],color='black')
plt.scatter(df1['income'],df1['score'],color='yellow')
plt.scatter(df2['income'],df2['score'],color='blue')
plt.scatter(df3['income'],df3['score'],color='pink')
plt.scatter(df4['income'],df4['score'],color='purple')
plt.scatter(df5['income'],df5['score'],color='green')
plt.scatter(df6['income'],df6['score'],color='violet')
plt.scatter(df7['income'],df7['score'],color='orange')

plt.scatter(centers[0,0],centers[0,1],color='yellow',marker='*')
plt.scatter(centers[1,0],centers[1,1],color='black',marker='*')
plt.scatter(centers[2,0],centers[2,1],color='black',marker='*')
plt.scatter(centers[3,0],centers[3,1],color='black',marker='*')
plt.scatter(centers[4,0],centers[4,1],color='black',marker='*')
plt.scatter(centers[5,0],centers[5,1],color='black',marker='*')
plt.scatter(centers[6,0],centers[6,1],color='black',marker='*')
plt.scatter(centers[7,0],centers[7,1],color='black',marker='*')

plt.title('clustering plot')
plt.xlabel('income')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %%
# Hypertuning to select optimum no. of cluster

# %%
ED_from_centers=[]
clusters = range(1,20)
for i in clusters:
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(df[['income','score']])
    ED_from_centers.append(kmeans.inertia_)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
ED_from_centers
# Out:
# [269981.28000000014,
#  181363.59595959607,
#  106348.37306211119,
#  73679.78903948837,
#  44448.45544793369,
#  37265.86520484345,
#  30259.657207285458,
#  25056.895153616188,
#  22787.737043908466,
#  19657.783608703947,
#  18210.045129650603,
#  15808.588580096657,
#  14292.543823365135,
#  12960.446844821845,
#  11927.413690476189,
#  10909.4628094128,
#  10087.592078754577,
#  9725.349610389609,
#  8911.960978835972]

# %%
plt.plot(clusters,ED_from_centers)
plt.title('elbow method')
plt.xlabel('no of clusters')
plt.ylabel('Euclidean distance')
# Out:
# Text(0, 0.5, 'Euclidean distance')

# %%
# !pip install kneed

# %%
from kneed import KneeLocator

# %%
kneedle=KneeLocator(clusters,ED_from_centers)

# %%
kneedle

# %%
optimal_cluster=kneedle.knee

# %%
optimal_cluster
# Out:
# 1

# %%
kneedle.plot_knee()
