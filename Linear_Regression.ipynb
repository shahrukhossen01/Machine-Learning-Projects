# %%
import pandas as pd

# %%
df=pd.read_csv('/Height-Weight Data.csv')

# %%
df
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 3496  69.296830  185.649086
# 3497  70.542201  210.198845
# 3498  73.912549  202.429960
# 3499  67.396021  144.277671
# 3500  72.738970  187.222909
#
# [3501 rows x 2 columns]

# %%
x=df[['Height']]

# %%
x
# Out:
#          Height
# 0     73.847017
# 1     68.781904
# 2     74.110105
# 3     71.730978
# 4     69.881796
# ...         ...
# 3496  69.296830
# 3497  70.542201
# 3498  73.912549
# 3499  67.396021
# 3500  72.738970
#
# [3501 rows x 1 columns]

# %%
y=df[['Weight']]

# %%
y
# Out:
#           Weight
# 0     241.893563
# 1     162.310473
# 2     212.740856
# 3     220.042470
# 4     206.349801
# ...          ...
# 3496  185.649086
# 3497  210.198845
# 3498  202.429960
# 3499  144.277671
# 3500  187.222909
#
# [3501 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Height'],df['Weight'],color='blue')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Height-Wight')
# Out:
# Text(0.5, 1.0, 'Height-Wight')

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=.75)

# %%
xtrain
# Out:
#          Height
# 194   72.539354
# 2605  67.979057
# 2726  69.811520
# 1874  69.617764
# 2656  73.181767
# ...         ...
# 3374  65.077752
# 2320  70.365393
# 1066  66.695309
# 2575  68.411275
# 2024  64.981086
#
# [2625 rows x 1 columns]

# %%
xtrain.shape
# Out:
# (2625, 1)

# %%
xtest
# Out:
#          Height
# 1165  67.749207
# 1602  65.253671
# 3443  70.790632
# 2314  68.035095
# 3191  69.769604
# ...         ...
# 896   62.752878
# 682   69.509488
# 2446  68.874876
# 2667  68.005429
# 130   67.492193
#
# [876 rows x 1 columns]

# %%
xtest.shape
# Out:
# (876, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
a=lr.intercept_
a
# Out:
# array([-225.26432231])

# %%
b=lr.coef_
b
# Out:
# array([[5.97005521]])

# %%
lr.score(xtrain,ytrain)
# Out:
# 0.7315242632323673

# %%
lr.score(xtest,ytest)
# Out:
# 0.7348760573527024

# %%
pred_y=lr.predict(xtest)

# %%
pred_y
# Out:
# array([[179.20218271],
#        [164.30369502],
#        [197.35965983],
#        [180.90895248],
#        [191.26406786],
#        [180.4781524 ],
#        [183.60731188],
#        [193.08309616],
#        [162.7181634 ],
#        [184.46532171],
#        [243.55342914],
#        [206.93378531],
#        [179.01822453],
#        [164.1075765 ],
#        [223.36686631],
#        [188.1174674 ],
#        [176.9667433 ],
#        [174.41066028],
#        [185.64989839],
#        [186.38938346],
#        [193.78826582],
#        [155.47512944],
#        [192.10542857],
#        [172.93600793],
#        [186.05468562],
#        [180.07124185],
#        [178.1649809 ],
#        [186.67843239],
#        [176.46310645],
#        [190.48621426],
#        [169.75251921],
#        [172.86097884],
#        [206.04330393],
#        [216.72159625],
#        [175.71128958],
#        [155.44826521],
#        [175.6604828 ],
#        [197.75558189],
#        [194.14550485],
#        [172.43463284],
# ...

# %%
ytest
# Out:
#           Weight
# 1165  178.583627
# 1602  174.943978
# 3443  200.364978
# 2314  162.124431
# 3191  188.844172
# ...          ...
# 896   149.759706
# 682   203.985415
# 2446  177.133136
# 2667  194.754189
# 130   191.699605
#
# [876 rows x 1 columns]

# %%
df[['New Weight']]=lr.predict(x)

# %%
df
# Out:
#          Height      Weight  New Weight
# 0     73.847017  241.893563  215.606446
# 1     68.781904  162.310473  185.367442
# 2     74.110105  212.740856  217.177098
# 3     71.730978  220.042470  202.973579
# 4     69.881796  206.349801  191.933857
# ...         ...         ...         ...
# 3496  69.296830  185.649086  188.441578
# 3497  70.542201  210.198845  195.876514
# 3498  73.912549  202.429960  215.997676
# 3499  67.396021  144.277671  177.093642
# 3500  72.738970  187.222909  208.991344
#
# [3501 rows x 3 columns]

# %%
plt.scatter(df['Height'],df['New Weight'],color='blue')
plt.xlabel('Height')
plt.ylabel('New Weight')
plt.title('Height-Wight')
# Out:
# Text(0.5, 1.0, 'Height-Wight')

# %%
import joblib as jb

# %%
jb.dump(lr,'My2')
# Out:
# ['My2']

# %%
model2=jb.load('My2')

# %%
model2.predict([[73.84]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([[215.56455406]])
